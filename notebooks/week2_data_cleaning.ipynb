# %%
import numpy as np
import pandas as pd


df = pd.read_csv('../data/raw/titanic.csv')
# print("======================================ALL DATA==========================================")
# print(df)
# print("=========================================================================================")
# print(df.head())
# print(df.info())
# print(df.describe())
print(df.shape)
print(df.dropna(subset=['Age'], how='all').shape)
# Out:
# (891, 12)
# (714, 12)
